# %% [markdown]
# # Contoh Klasifikasi

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import clear_output
from qiskit import QuantumCircuit
from qiskit.circuit import Parameter
from qiskit.circuit.library import RealAmplitudes, ZZFeatureMap
from qiskit_algorithms.optimizers import COBYLA, L_BFGS_B
from qiskit_algorithms.utils import algorithm_globals

from qiskit_machine_learning.algorithms.classifiers import NeuralNetworkClassifier, VQC
from qiskit_machine_learning.algorithms.regressors import NeuralNetworkRegressor, VQR
from qiskit_machine_learning.neural_networks import SamplerQNN, EstimatorQNN
from qiskit_machine_learning.circuit.library import QNNCircuit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 7
#       5 from qiskit.circuit import Parameter
#       6 from qiskit.circuit.library import RealAmplitudes, ZZFeatureMap
# ----> 7 from qiskit_algorithms.optimizers import COBYLA, L_BFGS_B
#       8 from qiskit_algorithms.utils import algorithm_globals
#      10 from qiskit_machine_learning.algorithms.classifiers import NeuralNetworkClassifier, VQC
#
# ModuleNotFoundError: No module named 'qiskit_algorithms'

# %% [markdown]
# #### Ambil dataset Iris

# %%
from sklearn.datasets import load_iris

iris_data = load_iris()

x = iris_data.data
y = iris_data.target

# %% [markdown]
# #### Normalisasi Data

# %%
from sklearn.preprocessing import MinMaxScaler
x_normal = MinMaxScaler().fit_transform(x)

# %% [markdown]
# #### Split Data

# %%
from sklearn.model_selection import train_test_split
from qiskit_algorithms.utils import algorithm_globals

algorithm_globals.random_seed = 123
train_x, test_x, train_y, test_y = train_test_split(x, y, train_size=0.8, random_state=algorithm_globals.random_seed)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 from qiskit_algorithms.utils import algorithm_globals
#       4 algorithm_globals.random_seed = 123
#       5 train_x, test_x, train_y, test_y = train_test_split(x, y, train_size=0.8, random_state=algorithm_globals.random_seed)
#
# ModuleNotFoundError: No module named 'qiskit_algorithms'

# %% [markdown]
# #### Parameterized Circuit: Feature Map

# %%
from qiskit.circuit.library import ZZFeatureMap

jum_fitur = x.shape[1]

feature_map = ZZFeatureMap(feature_dimension=jum_fitur, reps=1)
feature_map.decompose().draw(output="mpl", style="clifford", fold=20)

# %% [markdown]
# #### Parameterized Circuit: Ansatz

# %%
from qiskit.circuit.library import RealAmplitudes

ansatz = RealAmplitudes(num_qubits=jum_fitur, reps=3)
ansatz.decompose().draw(output="mpl", style="clifford", fold=20)

# %% [markdown]
# ### Optimasi pelatihan menggunakan algoritma COBYLA

# %%
from qiskit_algorithms.optimizers import COBYLA

optimizer = COBYLA(maxiter=100)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 from qiskit_algorithms.optimizers import COBYLA
#       3 optimizer = COBYLA(maxiter=100)
#
# ModuleNotFoundError: No module named 'qiskit_algorithms'

# %%
from qiskit.primitives import Sampler

sampler = Sampler()

# %% [markdown]
# ### Buat fungsi untuk menggambar proses pelatihan

# %%
from matplotlib import pyplot as plt
from IPython.display import clear_output

objective_func_vals = []
plt.rcParams["figure.figsize"] = (12, 6)


def callback_graph(weights, obj_func_eval):
    clear_output(wait=True)
    objective_func_vals.append(obj_func_eval)
    plt.title("Objective function value against iteration")
    plt.xlabel("Iteration")
    plt.ylabel("Objective function value")
    plt.plot(range(len(objective_func_vals)), objective_func_vals)
    plt.show()

# %% [markdown]
# ### Algoritma QML: VQC

# %%
import time
from qiskit_machine_learning.algorithms.classifiers import VQC

vqc = VQC(
    sampler=sampler,
    feature_map=feature_map,
    ansatz=ansatz,
    optimizer=optimizer,
    callback=callback_graph,
)

# %% [markdown]
# ### Pelatihan

# %%
objective_func_vals = []

start = time.time()
vqc.fit(train_x, train_y)
elapsed = time.time() - start

print(f"Training time: {round(elapsed)} seconds")

# %% [markdown]
# ### Pengujian

# %%
score_training = vqc.score(train_x, train_y)
score_test = vqc.score(test_x, test_y)

print(f"Quantum VQC on the training dataset: {score_training:.2f}")
print(f"Quantum VQC on the test dataset:     {score_test:.2f}")

# %% [markdown]
# # Reduksi Jumlah Fitur menggunakan PCA

# %%
from sklearn.datasets import load_iris

iris_data = load_iris()

# %%
features = iris_data.data
labels = iris_data.target

# %%
from sklearn.preprocessing import MinMaxScaler

features = MinMaxScaler().fit_transform(features)

# %%
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
import seaborn as sns

features = PCA(n_components=2).fit_transform(features)

plt.rcParams["figure.figsize"] = (6, 6)
sns.scatterplot(x=features[:, 0], y=features[:, 1], hue=labels, palette="tab10")

# %% [markdown]
# #### Split Data

# %%
train_x, test_x, train_y, test_y = train_test_split(features, labels, train_size=0.8, random_state=algorithm_globals.random_seed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 train_x, test_x, train_y, test_y = train_test_split(features, labels, train_size=0.8, random_state=algorithm_globals.random_seed)
#
# NameError: name 'features' is not defined

# %%
from qiskit.circuit.library import ZZFeatureMap
from qiskit.circuit.library import RealAmplitudes

num_features = features.shape[1]

feature_map = ZZFeatureMap(feature_dimension=num_features, reps=1)
ansatz = RealAmplitudes(num_qubits=num_features, reps=3)

# %%
optimizer = COBYLA(maxiter=40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 optimizer = COBYLA(maxiter=40)
#
# NameError: name 'COBYLA' is not defined

# %% [markdown]
# #### Pelatihan Model

# %%
vqc = VQC(
    sampler=sampler,
    feature_map=feature_map,
    ansatz=ansatz,
    optimizer=optimizer,
    callback=callback_graph,
)

# clear objective value history
objective_func_vals = []

# make the objective function plot look nicer.
plt.rcParams["figure.figsize"] = (12, 6)


start = time.time()
vqc.fit(train_x, train_y)
elapsed = time.time() - start

print(f"Training time: {round(elapsed)} seconds")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 vqc = VQC(
#       2     sampler=sampler,
#       3     feature_map=feature_map,
#       4     ansatz=ansatz,
#       5     optimizer=optimizer,
#       6     callback=callback_graph,
#       7 )
#       9 # clear objective value history
#      10 objective_func_vals = []
#
# NameError: name 'VQC' is not defined

# %%
train_score_q2_ra = vqc.score(train_x, train_y)
test_score_q2_ra = vqc.score(test_x, test_y)

print(f"Quantum VQC on the training dataset using RealAmplitudes: {train_score_q2_ra:.2f}")
print(f"Quantum VQC on the test dataset using RealAmplitudes:     {test_score_q2_ra:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 train_score_q2_ra = vqc.score(train_x, train_y)
#       2 test_score_q2_ra = vqc.score(test_x, test_y)
#       4 print(f"Quantum VQC on the training dataset using RealAmplitudes: {train_score_q2_ra:.2f}")
#
# NameError: name 'vqc' is not defined

# %% [markdown]
# #### Menggunakan Ansatz yang lain

# %%
from qiskit.circuit.library import EfficientSU2

ansatz = EfficientSU2(num_qubits=num_features, reps=3)
optimizer = COBYLA(maxiter=40)

vqc = VQC(
    sampler=sampler,
    feature_map=feature_map,
    ansatz=ansatz,
    optimizer=optimizer,
    callback=callback_graph,
)

# clear objective value history
objective_func_vals = []

start = time.time()
vqc.fit(train_x, train_y)
elapsed = time.time() - start

print(f"Training time: {round(elapsed)} seconds")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 3
#       1 from qiskit.circuit.library import EfficientSU2
# ----> 3 ansatz = EfficientSU2(num_qubits=num_features, reps=3)
#       4 optimizer = COBYLA(maxiter=40)
#       6 vqc = VQC(
#       7     sampler=sampler,
#       8     feature_map=feature_map,
#    (...)
#      11     callback=callback_graph,
#      12 )
#
# NameError: name 'num_features' is not defined

# %%
train_score_q2_eff = vqc.score(train_x, train_y)
test_score_q2_eff = vqc.score(test_x, test_y)

print(f"Quantum VQC on the training dataset using EfficientSU2: {train_score_q2_eff:.2f}")
print(f"Quantum VQC on the test dataset using EfficientSU2:     {test_score_q2_eff:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 train_score_q2_eff = vqc.score(train_x, train_y)
#       2 test_score_q2_eff = vqc.score(test_x, test_y)
#       4 print(f"Quantum VQC on the training dataset using EfficientSU2: {train_score_q2_eff:.2f}")
#
# NameError: name 'vqc' is not defined

# %% [markdown]
# # Contoh Regresi dengan Variational Quantum Regressor (VQR)

# %%
from sklearn.datasets import make_regression

X, y = make_regression(n_samples=50, n_features=5, noise=1, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

x = MinMaxScaler().fit_transform(X)

# %%
train_x, test_x, train_y, test_y = train_test_split(x, y, train_size=0.8, random_state=algorithm_globals.random_seed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 train_x, test_x, train_y, test_y = train_test_split(x, y, train_size=0.8, random_state=algorithm_globals.random_seed)
#
# NameError: name 'algorithm_globals' is not defined

# %%
from qiskit.circuit.library import ZZFeatureMap
from qiskit.circuit.library import RealAmplitudes

num_features = x.shape[1]

feature_map = ZZFeatureMap(feature_dimension=num_features, reps=1)
ansatz = RealAmplitudes(num_qubits=num_features, reps=3)

# %%
vqr = VQR(
    feature_map=feature_map,
    ansatz=ansatz,
    optimizer=L_BFGS_B(maxiter=5),
    callback=callback_graph,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 vqr = VQR(
#       2     feature_map=feature_map,
#       3     ansatz=ansatz,
#       4     optimizer=L_BFGS_B(maxiter=5),
#       5     callback=callback_graph,
#       6 )
#
# NameError: name 'VQR' is not defined

# %%
# create empty array for callback to store evaluations of the objective function
objective_func_vals = []
plt.rcParams["figure.figsize"] = (12, 6)

# fit regressor
vqr.fit(train_x, train_y)

# return to default figsize
plt.rcParams["figure.figsize"] = (6, 4)

# score result
vqr.score(train_x, train_y)

# %%
# score result
vqr.score(test_x, test_y)
